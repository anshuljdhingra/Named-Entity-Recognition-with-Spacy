# %%
import spacy 
#nlp = spacy.load('en_core_web_lg')
#nlp = spacy.load('en_vectors_web_lg')
nlp = spacy.load('en')
import re
import nltk
import pandas as pd
import numpy as np
from openpyxl import load_workbook
import os
import xlsxwriter
#from stopword import *
from xlrd import open_workbook, XLRDError
import warnings
warnings.filterwarnings("ignore")

# %%
loc = r'C:/Users/Anshul.Dhingra/Desktop/NER/Input/Website_Extraction_results.csv'
savepath = 'C://Users//Anshul.Dhingra//Desktop//NER//Input//webpages//'
newp = 'C://Users//Anshul.Dhingra//Desktop//NER//Input//webpages//'
excelpath = "C:\\Users\\Anshul.Dhingra\\Desktop\\NER\\Output\\"
filepath = 'C://Users//Anshul.Dhingra//Desktop//NER//Input//webpages//extracts//'
path = 'C://Users//Anshul.Dhingra//Desktop//NER//Input//webpages//'

# %%
​stop =  ['a','about','above','after','again','against','all','am','an','and','any','are','as','at','be',
         'because','been','before','being','below','between','both','but','by','could','did','do','does','doing',
         'down','during','each','few','for','from','further','had','has','have','having','he','her','here','hers',
         'herself','him','himself','his','how','I','if','in','into','is','it','it’s','its','itself','me','more','most',
         'my','myself','nor','of','on','once','only','or','other','ought','our','ours','ourselves','out','over','own',
         'same','should','so','some','such','than','that','the','their','theirs','them','themselves','then','there','there’s',
         'these','they','this','those','through','to','too','under','until','up','very','was','we','were','what','when',
         'where','which','while','who','whom','why','with','would','you','your','yours','yourself','yourselves','\xa0410-975-0099','\xa0','https://1northwealthservices.com/','usStart','Login','ServiceWe','Chair','\xa0410-975-0099', '\xa0','https://1northwealthservices.com/','usStart','Login ', 'ServiceWe ', 'Chair ',
         '410-975-0099','MoreJames BrennanBlog', 'BrennanBlog' ,'James BrennanBlog','MoreJames BrennanBlog ',
         'Start ','usStart ','James Brennan ','Get ', 'Get ', 'Skip ', 'https://3dwealthadvisors.com/  ',
          'Learn ', 'Download ', 'Learn ','Request', ' ', 'Inc.', 'Inc','3rd Creek - Investments', 
         '3rd Creek3rd Creek ', '© ', '3rd Creek3rd ' ,' Accounting,','Accounting,','Registered Representative ',
          'Dave StraleyDave Straley ','3CI ', 'DBS CPA', 'Dave Straley ', 'Jane ', 'Dave ', '3rd ','Tech Sector ', 'Tech Sector',' Tech Sector ',' Tech Sector', 'HomeBlog ', ' HomeBlog ', ' HomeBlog', 'HomeBlog','Volatile Market', ' Volatile Market', ' Volatile Market ', 'Volatile Market ','the@financial'  ,' the@financial', ' the@financial ', 'the@financial ', 'FINANCIAL@financial' , ' FINANCIAL@financial ',' FINANCIAL@financial', 'FINANCIAL@financial ', 'Certification Exam'  ,' Certification Exam ', 'Certification Exam ' ,' Certification Exam' , 'Find ', ' Find ', ' Find','Find', 'Terms of UseTerms of Use ', 'Terms of UseTerms of Use', ' Terms of UseTerms of Use ' , ' Terms of UseTerms of Use', 'Toggle ', ' Toggle ', 'Toggle', ' Toggle','http://www.1650wealth.com/difference/the-fee-only-difference/ ', 'http://www.1650wealth.com/difference/the-fee-only-difference/', ' http://www.1650wealth.com/difference/the-fee-only-difference/', ' http://www.1650wealth.com/difference/the-fee-only-difference/',  
         'Jane BurnhamJane ','3rd Creek - Contact — 3rd Creek - Investments', 'info@3rdcreek.comWe ', 'Contact '
         'Gwen StraleyGwen Straley ', 'Harris KirschnerHarris ', 'Gwen ',  'Gwen Straley', '', 'Account',
         'Dave B. StraleyDave Straley ', 'Harris ', 'Admin Login ', 'FINRA ', 'Why Choose Us', 
         'Fixed Income ', 'Investment ','Jerry) Warrington', 'Jr. ', 'Jerry ','W. Gerald “Jerry” Warrington',
          'Noel R. Caldwell', 'W. Gerald “', 'Noel ','component&link=8e300a0aceae54db60880073dc561f2e5f36539c', 
         'Menu', 'Mobile', 'component&print=1&page=','Friday ', 'GE ', 'Contact ', 'Micron Poised ', 'Complimentary '
         'Download', 'c7e0741a15873c5b66e284bf6774ec6267b55cbf', 'Podcast',' Complimentary ','Download','Accounting',
         'LLC ', 'LIC.#0F30083CA INS', 'LLCInvestment ', 'LIC.#0F30083 ', '12-Squared ',  'Proudly ' ,
          'LLC – Investment ', 'LIC.#0F30083 Home ', 'a Registered Investment Adviser', 'Home ','Your Privacy',
         'clients’ ', 'Download Your Copy ', 'Content  Learn ', 'Featured InWelcome ', 'Welcome ',
         'Featured InOFFICE LOCATION',  'We','Connect ', 'Will ', 'Knowledgeably Applied', 'MeForgot ',
          'Directions ','Approach','Contact Us','SubmitFullName FullName', 'Submit', 'Buffett', 'Select', 
         'SubmitFullName',  'Warren', 'Submit','Menu', ' HOME', 'Menu', ' HOME', ' Menu ', ' Menu', ' HOME',
         ' HOME', ' Menu ', ' Menu','HOME', 'Menu ','Feel ',  'Email Address ',  'Twitter ', 'N. Clybourn Ave',
         'Evanston', 'Clybourn Ave', 'W Fulton', 'Lead Investment ', 'Reach ',' Contact - 1 North Wealth Services',
         ' Contact - 1 North Wealth Services ', 'Contact - 1 North Wealth Services', 'Contact - 1 ','Contact - 1'
          ' Contact - 1 ', 'B.A.', 'B.A. ', ' B.A.', ' Contact - 1 ','Nicaragua', ' Managua', 
          'Gwen StraleyGwen Straley ', ' Gwen StraleyGwen Straley ', 'Gwen StraleyGwen Straley',
          ' Gwen StraleyGwen Straley', 'Somalia', 'Palestine', ' Complimentary ' ,'  Welcome ', ' Featured In', ' Learn ', ' Welcome ', ' Roth ', ' Featured ', ' Featured InWelcome ',
         ' http://www.1650wealth.com/difference/the-fee-only-difference/','Featured In',  'Featured ',' AFFILIATIONS','http://www.naepc.org/  :',  ' Fee'
         'Featured ', ' \xa0“de Waal Straat”', '  ', ' Featured ', 'Process',' Process', ' Process ', 'Process ',
         ' http://www.1650wealth.com/difference/the-fee-only-difference/','“de Waal Straat”', 'Featured ',
         'INDEPENDENT',' INDEPENDENT','INDEPENDENT ',' INDEPENDENT ',' Adjunct Professor ',' Registered Rep',
         ' Bachelor ', ' Adjunct ',' Tom ', 'Tom ',' Award Winner',' Featured ', ' Nashua', 'Tom',
         ' http://www.1650wealth.com/difference/the-fee-only-difference/','Registered Rep', 'Bachelor ', 'Adjunct ',
         'Bloomberg Businessweek', 'AFFILIATIONS', 'Tom ', 'Award Winner', 'Featured ','Download Your Copy ',
         'Featured ', '\xa0', ' Featured ', ' http://www.1650wealth.com/difference/the-fee-only-difference/',
         ' Featured ','Featured ','AFFILIATIONS','Discuss ', 'Featured ','“de Waal Straat”', 'Featured ',
         ' New Amsterdam',' INDEPENDENT','Failure ', 'Certified Financial ', 'a Governance Fellow',
         'Certified Financial Planner ', 'Boards ', 'Sean ', 'Sean ','Nationally ', 'Sean ', 'NEXT BIO',
         'Tax Planning ', 'Schwab ', 'LLP', 'Our StoryThe Value ', 'Convert ', 'Roth Conversions', 'NABCAP Award ', 
         'Roth ConversionsThink Long ', 'Legacy Planning ', 'NABCAP Award', 'Roth Conversions ', 'Tucker ',
         'William S. Richardson School of Law ', 'Our Story - Independent', 'Award ',' Fee', 'Process',' Process', ' Process ', 'Process ',
         ' Our StoryThe Value ',' First', ' Convert ', ' Michelle ', ' Roth Conversions',' NABCAP Award ',
         ' Skip ', 'Michelle', ' Roth ConversionsThink Long ', ' https://3dwealthadvisors.com/  ','Bob ',  'ted@advwealth.com            ', 'Lindsey ', 'the Top\xa0', 'Clevenger ', 'Traci Nelson', 'Reanna Pechner ', 'Ted’s ', 'Matter Expert ', 'Veronica ', 'Veronica ShafferOperations ', 'Dorothy HaleyBusiness ', 'Dorothy ', 'Veronica ShafferVeronica Shaffer', 'Business ', 'Bob ', 'ted@advwealth.com            Ted ', 'Lindsey ',  'Linda ', 'Lindsey HaleyLindsey HaleyBusiness ', 'PLANNER™ ', 'Lindsey HaleyBusiness ','Ted ', 
         ' Home', ' Legacy Planning ', 'NABCAP Award', ' Roth Conversions ', ' Tucker ','Mary Lu ',' Mary Lu ', 'Mary Lu', ' Mary Lu',
         ' William S. Richardson School of Law ', ' Our Story - Independent', ' Award ', ' Fee','Complimentary ',
        'Adjunct Professor ',' Navigation',' Bio - Deanna Suarez','Thoughtful ','Ending ', 'Building ','Kate ',' Kate ','Kate', ' Kate',
          'Write ', 'Building ', 'Registered Investment Adviser',' Wealth Advisorsâ€', '& ', 'Â\xa0  ','Â\xa0Lindsey HaleyBusiness ','Â\xa0Veronica Shaffer',
         'Starting ', 'Starting ',' Commonwealth',' Waiting','Â\xa0Our ', 'Â\xa0Our Services', 'Â\xa0Our Services', 'Â\xa0Our Services', 'Â\xa0Building ', 'F503.452.7820 ', 'F503.452.7820  ', 'Waiting ', 'Â\xa0Building ','Ã—', ' Â\xa0Our ', ' Â\xa0Our Services', ' Â\xa0Â', ' Â\xa0Our Services', '  ', ' Â\xa0Our Services', ' Ã—', ' Â\xa0Building ', ' F503.452.7820 ', ' Ã—', ' Ã—', ' Ã—', ' F503.452.7820  ', ' \xa0Building ', ' Waiting ', ' Â\xa0', ' Â\xa0',
         ' FINRA/SIPC', ' \xa0', ' Â\xa0', ' Â\xa0Building ','able','about','above','according','accordingly',
         'across','actually','after','afterwards','again','against','all','allow','allows','almost','alone',
         'along','already','also','although','always','am','among','amongst','an','and','another','any','anybody',
         'anyhow','anyone','anything','anyway','anyways','anywhere','apart','appear','appreciate','appropriate','are',
         'around','as','aside','ask','asking','associated','at','available','away','awfully','be','became','because','Kate ',
         'become','becomes','becoming','been','before','beforehand','behind','being','believe','below','beside','besides',
         'best','better','between','beyond','both','brief','but','by','came','can','cannot','cant','cause','causes','certain',
         'certainly','changes','clearly','co','com','come','comes','concerning','consequently','consider','considering',
         'contain','containing','contains','corresponding','could','course','currently','definitely','described','despite',
         'did','didn’t','different','do','does','doing','done','down','downwards','during','each','edu','eg','eight','either',
         'else','elsewhere','enough','entirely','especially','et','etc','even','ever','every','everybody','everyone',
         'everything','everywhere','ex','exactly','example','except','far','few','fifth','first','five','followed',
         'following','follows','for','former','formerly','forth','four','from','further','furthermore','get',
         'gets','getting','given','gives','go','goes','going','gone','got','gotten','greetings','had','happens',
         'hardly','has','have','having','he','hello','help','hence','her','here','hereafter','hereby','herein',
         'hereupon','hers','herself','hi','him','himself','his','hither','hopefully','how','howbeit','however']

# %%
#nlp = spacy.load('en_web_core_sm')

# %%
def strip_url(url):
    return re.sub('\W+','', url)

# %%
import xlrd
import csv

import pandas as pd 
df2 = pd.read_csv(loc, header=None)

# %%
df2.head()
# Out:
#                     0                                            1        2  \
# 0  www.12-squared.com                    http://www.12-squared.com  Success
# 1                 NaN                                          NaN      NaN
# 2  www.1650wealth.com                    http://www.1650wealth.com  Success
# 3                 NaN                                          NaN      NaN
# 4  www.1650wealth.com  http://www.1650wealth.com/who-we-are/story/  Success
#
#      3
# 0  NaN
# 1  NaN
# 2  NaN
# 3  NaN
# 4  NaN

# %%
#test = list(range(0,22)) + list(range(23,53))

# %%
#df2 = df2.iloc[list(range(0,22)) + list(range(23,53)), :]

# %%
df2.drop(labels=[3], axis=1, inplace=True)

# %%
df2.dropna(axis=0, inplace=True)

# %%
df2.head()
# Out:
#                     0                                               1        2
# 0  www.12-squared.com                       http://www.12-squared.com  Success
# 2  www.1650wealth.com                       http://www.1650wealth.com  Success
# 4  www.1650wealth.com     http://www.1650wealth.com/who-we-are/story/  Success
# 6  www.1650wealth.com  http://www.1650wealth.com/who-we-are/our-team/  Success
# 8  www.1650wealth.com                     http://www.1650wealth.com/#  Success

# %%
df2['main'] = df2[0].apply(lambda x: strip_url(x))

# %%
df2['ind'] = df2[1].apply(lambda x: strip_url(x))

# %%
df2.reset_index(drop=True,inplace=True)

# %%
df2.head()
# Out:
#                     0                                               1  \
# 0  www.12-squared.com                       http://www.12-squared.com
# 1  www.1650wealth.com                       http://www.1650wealth.com
# 2  www.1650wealth.com     http://www.1650wealth.com/who-we-are/story/
# 3  www.1650wealth.com  http://www.1650wealth.com/who-we-are/our-team/
# 4  www.1650wealth.com                     http://www.1650wealth.com/#
#
#          2              main                                  ind
# 0  Success   www12squaredcom                  httpwww12squaredcom
# 1  Success  www1650wealthcom                 httpwww1650wealthcom
# 2  Success  www1650wealthcom    httpwww1650wealthcomwhowearestory
# 3  Success  www1650wealthcom  httpwww1650wealthcomwhoweareourteam
# 4  Success  www1650wealthcom                 httpwww1650wealthcom

# %%
#df2[2][0] = 'Fail'

# %%
#df2.loc[df2[2] == 'Success'][['main', 'ind']]

# %%
web_dict = dict(zip(df2['ind'], df2[1]))

# %%
print(web_dict)
# Out:
# {'httpwww12squaredcom': 'http://www.12-squared.com',
#  'httpwww1650wealthcom': 'http://www.1650wealth.com/#',
#  'httpwww1650wealthcomwhowearestory': 'http://www.1650wealth.com/who-we-are/story',
#  'httpwww1650wealthcomwhoweareourteam': 'http://www.1650wealth.com/who-we-are/our-team/',
#  'httpwww1650wealthcomcontactusouroffices': 'http://www.1650wealth.com/contact-us/our-offices/',
#  'httpwww1650wealthcomcontactuscomplimentaryconsultation': 'http://www.1650wealth.com/contact-us/complimentary-consultation/',
#  'httpwww1650wealthcomwhyarewedifferentwhy1650wealth': 'http://www.1650wealth.com/why-are-we-different/why-1650-wealth//',
#  'httpletsmakeaplanorgchooseacfpprofessionalwhycfpcertificationmatters': 'http://letsmakeaplan.org/choose-a-cfp-professional/why-cfp-certification-matters',
#  'httpwwwfpanetorgWhatisFinancialPlanningWhyaCFPProfessional': 'http://www.fpanet.org/WhatisFinancialPlanning/WhyaCFPProfessional/',
#  'httpwww3rdcreekcom': 'http://www.3rdcreek.com',
# ...

# %%
df2 = df2.loc[df2[2] == 'Success']

# %%
df2.head()
# Out:
#                     0                                               1  \
# 0  www.12-squared.com                       http://www.12-squared.com
# 1  www.1650wealth.com                       http://www.1650wealth.com
# 2  www.1650wealth.com     http://www.1650wealth.com/who-we-are/story/
# 3  www.1650wealth.com  http://www.1650wealth.com/who-we-are/our-team/
# 4  www.1650wealth.com                     http://www.1650wealth.com/#
#
#          2              main                                  ind
# 0  Success   www12squaredcom                  httpwww12squaredcom
# 1  Success  www1650wealthcom                 httpwww1650wealthcom
# 2  Success  www1650wealthcom    httpwww1650wealthcomwhowearestory
# 3  Success  www1650wealthcom  httpwww1650wealthcomwhoweareourteam
# 4  Success  www1650wealthcom                 httpwww1650wealthcom

# %%
df3 = df2.groupby(by='main')

# %%
#savepath = 'C://Users//Anshul.Dhingra//Desktop//NER//Input//webpages//'
for i in df2.main.unique():
    #print(i)
    fil =  i + '.txt'
    print(fil)
    with open((os.path.join(savepath,fil)), 'w+', encoding = 'utf-8') as f:
        #print(f)
        for j in df3.get_group(i)['ind']:
            print(j)
            text = ""
            text = str(j) + '.txt'
            f.write(text)
            f.write('\n')
    #print(df3.get_group(i)['ind'])
# Out:
# www12squaredcom.txt
# httpwww12squaredcom
# www1650wealthcom.txt
# httpwww1650wealthcom
# httpwww1650wealthcomwhowearestory
# httpwww1650wealthcomwhoweareourteam
# httpwww1650wealthcom
# httpwww1650wealthcomcontactusouroffices
# httpwww1650wealthcomcontactuscomplimentaryconsultation
# httpwww1650wealthcomwhowearestory
# httpwww1650wealthcomwhyarewedifferentwhy1650wealth
# httpletsmakeaplanorgchooseacfpprofessionalwhycfpcertificationmatters
# httpwwwfpanetorgWhatisFinancialPlanningWhyaCFPProfessional
# httpwww1650wealthcom
# httpwww1650wealthcomwhowearestory
# httpwww1650wealthcomwhoweareourteam
# httpwww1650wealthcom
# httpwww1650wealthcomcontactusouroffices
# httpwww1650wealthcomcontactuscomplimentaryconsultation
# httpwww1650wealthcomwhowearestory
# httpwww1650wealthcomwhyarewedifferentwhy1650wealth
# httpletsmakeaplanorgchooseacfpprofessionalwhycfpcertificationmatters
# httpwwwfpanetorgWhatisFinancialPlanningWhyaCFPProfessional
# www3rdcreekcom.txt
# httpwww3rdcreekcom
# ...

# %%
#a = df3.get_group(df2.main.unique()[1])['ind']

# %%
#newp = 'C://Users//Anshul.Dhingra//Desktop//NER//Input//webpages//'
fname = []
import glob, os
os.chdir(newp)
for file in glob.glob("*.txt"):
    fname.append(file)

#fname.append('abc.txt')

# %%
print(fname)
# Out:
# ['www12squaredcom.txt', 'www1650wealthcom.txt', 'www1776wealthcom.txt', 'www1northwealthservicescom.txt', 'www3dwealthadvisorscom.txt', 'www3rdcreekcom.txt', 'www3rdstreetcapcom.txt', 'wwwadvwealthcom.txt', 'wwwatfinancialeducom.txt']

# %%
import glob, os, os.path

filelist = glob.glob(os.path.join(excelpath, "*.csv"))
for f in filelist:
    os.remove(f)

# %%
'''#path = 'C://Users//Anshul.Dhingra//Desktop//NER//Input//webpages//'
for f_ in fname:
    excelworkbook = f_.split('.')[0] + '.xlsx'
    #excelpath = "C:\\Users\\Anshul.Dhingra\\Desktop\\NER\\Output\\"
    excelfinal = (os.path.join(excelpath, excelworkbook))
    print(excelworkbook)
    workbook = xlsxwriter.Workbook(excelfinal)
    worksheet = workbook.add_worksheet()'''
# Out:
# '#path = \'C://Users//Anshul.Dhingra//Desktop//NER//Input//webpages//\'\nfor f_ in fname:\n    excelworkbook = f_.split(\'.\')[0] + \'.xlsx\'\n    #excelpath = "C:\\Users\\Anshul.Dhingra\\Desktop\\NER\\Output\\"\n    excelfinal = (os.path.join(excelpath, excelworkbook))\n    print(excelworkbook)\n    workbook = xlsxwriter.Workbook(excelfinal)\n    worksheet = workbook.add_worksheet()'

# %%
#path = 'C://Users//Anshul.Dhingra//Desktop//NER//Input//webpages//'
for f_ in fname: #
    with open(os.path.join(path, f_), encoding='utf-8', errors='ignore') as f:
        content = f.readlines()
    content = [x.strip() for x in content] 
    print(content)
    #startrow=0
    #filepath = 'C://Users//Anshul.Dhingra//Desktop//NER//Input//webpages//extracts//'
    for c in content:
        print(c)
        with open((os.path.join(filepath,c)), 'r', encoding = 'utf-8', errors='ignore') as myfile:
            #file=myfile.read().replace('\n', ' ')
            file=myfile.read().rstrip('\r\n')
            document = nlp(file)
            entities = [e.string for e in document.ents if 'PERSON'==e.label_] 
            entities = list((set(entities)))
            print (entities)
            names = []
            for word in entities:
                if word not in stop:
                    print(word)
                    word.replace("\n", "")
                    word.replace("\t", "")
                    #word.replace("  ", "")
                    names.append(word)
            names = set(names)
            names = ', '.join(names)
            #names = names.replace('"', '\'')
            names = names.replace('\n', '')
            l = names.split(',')
            print(l)
            final_names = []
            for word in l:
                if re.match(r'\s', word):
                    word = word.lstrip()

                if " " in word:
                    final_names.append(word)
            final_names = [name for name in final_names if name not in stop]
            print(final_names)
            def extract_phone_numbers(file):
                r = re.compile(r'(\d{3}[-\.\s]??\d{3}[-\.\s]??\d{4}|\(\d{3}\)\s*\d{3}[-\.\s]??\d{4}|\d{3}[-\.\s]??\d{4})')
                phone_numbers = r.findall(file)
                return [re.sub(r'\D', '', number) for number in phone_numbers]

            def extract_email_addresses(file):
                r = re.compile(r'[\w\.-]+@[\w\.-]+')
                return r.findall(file)

            numbers = set(extract_phone_numbers(file))
            emails = set(extract_email_addresses(file))

            doc = nlp(file)
            company = []
            for ent in doc.ents:
                 if ent.label_ == 'GPE'  and ent.text not in company: #ent.label_ == 'LOC' or
                    company.append(ent.text)
            print (set(company))

            address = []
            for word in set(company):
                if word not in stop:
                    print(word)
                    word.replace("\n", "")
                    word.replace("\t", "")
                    #word.replace("  ", "")
                    address.append(word)
            address = ', '.join(address)
            #names = names.replace('"', '\'')
            address = address.replace('\n', '')

            print(address)

            l2 =address.split(',')
            print(l2)
            final_address = []
            for word in l2:
                word = word.strip()
                final_address.append(word)
            #    if re.match(r'\s', word):

            
            final_address = [add for add in final_address if add not in stop]
            print(final_address) 
            
            df = pd.DataFrame(data = [final_names, final_address, list(numbers), list(emails)])
            df = df.T
            df.columns = ['Name', 'Address', 'Contact#', 'Email']
            df['Title'] = ' '
            df['URL'] = c
            df['URL'] = df['URL'].apply(lambda x: x.split('.')[0])
            #df['URL'] = df['URL'][0]
            df['URL'] = df['URL'].map(web_dict)
            df['URL'] = df['URL'].drop_duplicates(keep='first')
            df.fillna(value = ' ', inplace=True)
            df = df[['Name', 'Title','Address', 'Contact#', 'Email', 'URL']]
            print(df)
            
            mycsv = f_.split('.')[0] + '.csv'
            with open(os.path.join(excelpath, mycsv), 'a') as f:
                df.to_csv(f, header=True, sep=',', encoding='utf-8', index=False)
                f.write(' ')
                f.write(" ")
# Out:
# ['httpwww12squaredcom.txt']
# httpwww12squaredcom.txt
# ['LIC.#0F30083\n\n\n\n\n\n \n\nHome ', 'LIC.#0F30083\nCA INS', '\t\t\t\n\n\n\t\t\t\tProudly ', 'Brad Gross CFP', 'LLC\nInvestment ', 'LLC – Investment ', '\n\n\n\n\n\n\n\n12-Squared ', 'a Registered Investment Adviser', 'LIC.#0F30083 \n\n\n', '\n\n\n\n\n\n\n\n\n\n \n\nHome ', '\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\nSkip ', 'LLC ', '\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\nSkip ']
# LIC.#0F30083
#
#
#
#
#
#
#
# Home
# LIC.#0F30083
# CA INS
#
#
#
# 				Proudly
# Brad Gross CFP
# LLC
# Investment
#
#
#
#
#
#
#
#
# 12-Squared
# LIC.#0F30083
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Home
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Skip
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Skip
# ...
